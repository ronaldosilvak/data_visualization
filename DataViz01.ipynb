# %% [markdown]
# <a href="https://colab.research.google.com/github/RonaldoSi/data_visualization/blob/main/DataViz01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/imigrantes_canada.csv')

# %%
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %%
df.set_index(['País'], inplace=True)

# %%
df
# Out:
#                 Continente            Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia       Sul da Ásia    16    39    39    47    71
# Albânia             Europa     Sul da Europa     1     0     0     0     0
# Argélia             África   Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia         Polinésia     0     1     0     0     0
# Andorra             Europa     Sul da Europa     0     0     0     0     0
# ...                    ...               ...   ...   ...   ...   ...   ...
# Vietnã                Ásia  Sudeste Asiático  1191  1829  2162  3404  7583
# Saara Ocidental     África   Norte da África     0     0     0     0     0
# Iémen                 Ásia    Ásia Ocidental     1     2     1     6     0
# Zâmbia              África   África Oriental    11    17    11     7    16
# Zimbábue            África   África Oriental    72   114   102    44    32
#
# ...

# %%
anos = list(map(str, range(1980,2014)))

# %%
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
brasil = df.loc['Brasil',  anos]
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
brasil_dict = {'ano': brasil.index.tolist(), 'imigrantes': brasil.values.tolist()}
dados_brasil = pd.DataFrame(brasil_dict)

# %%
dados_brasil
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 4))

plt.title('Imigração: Brasil -> Canadá')
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.yticks([500, 1000, 1500, 2000, 2500, 3000])
plt.xlabel('Ano')
plt.ylabel('Quantidade de Imigrantes')
# Out:
# Text(0, 0.5, 'Quantidade de Imigrantes')

# %% [markdown]
# # **Desafio**
#
# Neste momento temos uma nova demanda: criar um gráfico de linhas comparando os números de imigrantes do Brasil e Argentina para o Canadá, que são os maiores países da América do Sul.

# %%
df
# Out:
#                 Continente            Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia       Sul da Ásia    16    39    39    47    71
# Albânia             Europa     Sul da Europa     1     0     0     0     0
# Argélia             África   Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia         Polinésia     0     1     0     0     0
# Andorra             Europa     Sul da Europa     0     0     0     0     0
# ...                    ...               ...   ...   ...   ...   ...   ...
# Vietnã                Ásia  Sudeste Asiático  1191  1829  2162  3404  7583
# Saara Ocidental     África   Norte da África     0     0     0     0     0
# Iémen                 Ásia    Ásia Ocidental     1     2     1     6     0
# Zâmbia              África   África Oriental    11    17    11     7    16
# Zimbábue            África   África Oriental    72   114   102    44    32
#
# ...

# %%
df_comparacao = df.loc[['Argentina', 'Brasil'], anos]
df_comparacao = df_comparacao.T # .T = Transpose(transpor)

# %%
df_comparacao
# Out:
# País  Argentina  Brasil
# 1980        368     211
# 1981        426     220
# 1982        626     192
# 1983        241     139
# 1984        237     145
# 1985        196     130
# 1986        213     205
# 1987        519     244
# 1988        374     394
# 1989        538     650
# 1990        678     650
# 1991        763     877
# 1992       1023    1066
# 1993       1022     866
# 1994        366     566
# 1995        380     572
# 1996        396     586
# 1997        391     591
# 1998        349     531
# 1999        318     626
# 2000        427     845
# 2001        635     847
# 2002        865     745
# 2003       1745     839
# 2004       1591     917
# 2005       1153     969
# 2006        847    1181
# 2007        620    1746
# 2008        540    2138
# 2009        467    2509
# 2010        459    2598
# 2011        278    1508
# 2012        263    1642
# 2013        282    1714

# %%
plt.plot(df_comparacao['Brasil'], label='Brasil')
plt.plot(df_comparacao['Argentina'], label='Argentina')

plt.title('Imigrantes: Brasil e Argentina -> Canadá')
plt.xlabel('Ano')
plt.ylabel('Número de imigrantes')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.yticks([500, 1000, 1500, 2000, 2500, 3000])
plt.legend();

# %% [markdown]
# # **Retomando o conteúdo...**

# %% [markdown]
# Customizando ainda mais os gráficos

# %%
# criando um gráfico como figura
fig, ax = plt.subplots(figsize=(8,4))

ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
ax.set_title('Imigração do Brasil para o Canadá\n1980-2013')
ax.set_xlabel('Ano')
ax.set_ylabel('Número de imigrantes')
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # colocando os anos de 5 em 5 de forma mais fácil
plt.show()

# %%
# criando múltiplos gráficos
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].plot(dados_brasil['ano'], dados_brasil['imigrantes'])
axs[0].set_title('Imigração do Brasil para o Canadá\n1980-2013')
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
axs[0].set_xlabel('Ano')
axs[0].set_ylabel('Número de imigrantes')
axs[0].grid()

axs[1].boxplot(dados_brasil['imigrantes'])
axs[1].set_title('Imigração do Brasil para o Canadá')
axs[1].set_xlabel('Brasil')
axs[1].set_ylabel('Número de imigrantes')
axs[1].grid()

plt.show()

# %%
dados_brasil.describe()
# Out:
#         imigrantes
# count    34.000000
# mean    872.323529
# std     663.401232
# min     130.000000
# 25%     428.250000
# 50%     697.500000
# 75%    1041.750000
# max    2598.000000

# %%
# criar gráficos com quatro subplots

fig, axs = plt.subplots(2,2, figsize=(10,6))
fig.suptitle('Taxas de imigração dos quatro maiores países da América do Sul para o Canadá')
fig.subplots_adjust(hspace=0.5, wspace=0.3)
# hspace -> ajustar espaço horizontal
# wspace -> ajustar espaço vertical
# assim dando mais espaçamento entre os gráficos

axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')


# realizando o ajuste no xlabel de forma conjunta com "for", onde os valores estavam todos sobrepostos
for ax in axs.flat:
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# setando títulos nos eixos de forma cojunta em todos os gráficos
for ax in axs.flat:
  ax.set_xlabel('Ano')
  ax.set_ylabel('Número de imigrantes')

ymin = 0
ymax = 7000

for axs in axs.ravel():
  axs.set_ylim(ymin, ymax)

plt.show()

# %% [markdown]
# # **Exercício 02**
#
# Você trabalha como Analista de Dados em uma empresa de varejo e recebeu a tarefa de criar uma figura com subplots que apresente a variação no número de vendas em quatro diferentes lojas ao longo de um ano. A gerência da empresa precisa visualizar de forma clara as tendências de vendas em cada loja, para que possam tomar decisões estratégicas sobre os estoques e ações de marketing. Para isso, você deve criar quatro subplots dispostos em duas linhas e duas colunas, onde cada subplot representa uma loja diferente. Nesse desafio, cada subplot deve apresentar um gráfico de linhas que mostre a variação do número de vendas ao longo dos meses do ano.

# %%
lojas = ['A', 'B', 'C', 'D']

vendas_2022 = {'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250]
}

# %%
df_desafio = pd.DataFrame(vendas_2022, index=lojas)
df_desafio
# Out:
#    Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
fig, axs = plt.subplots(2,2, figsize=(12,6))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle('Indíce de vendas para as lojas A, B, C e D')

axs[0,0].plot(df_desafio.loc['A'])
axs[0,0].set_title('Loja A')

axs[0,1].plot(df_desafio.loc['B'])
axs[0,1].set_title('Loja B')

axs[1,0].plot(df_desafio.loc['C'])
axs[1,0].set_title('Loja C')

axs[1,1].plot(df_desafio.loc['D'])
axs[1,1].set_title('Loja D')

for ax in axs.flat:
  ax.set_xlabel('Mês')
  ax.set_ylabel('Quantidade de vendas')

# %% [markdown]
# # **Retomando o conteúdo...**

# %% [markdown]
# Aprendendo alguns parâmetros, como:
#
# lw -> aumenta a espessura das linhas do gráfico
#
# marker -> realiza a plotagem de marcadores no gráfico
#
# loc (título) -> usando para definirmos a disposição do título
#
# grid -> adiciona linhas de grade ao gráfico
#
# linestyle -> podemos passar parâmetros para modificar as linhas de grade, exemplo("--")

# %%
# criando um gráfico como figura
fig, ax = plt.subplots(figsize=(8,4))

ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3, marker='o', color='green') # lw -> aumentar espessura da linha
ax.set_title('Imigração do Brasil para o Canadá\n1980-2013', fontsize=18, loc='left') # loc -> serve para alterarmos onde o título vai ficar disposto
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Número de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12) # alterando o tamanho dos valores do eixo x
ax.yaxis.set_tick_params(labelsize=12) # alterando o tamanho dos valores do eixo y
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # colocando os anos de 5 em 5 de forma mais fácil
plt.grid(linestyle='--') # adiciona grade ao gráfico

plt.show()

# %% [markdown]
# Adicionando cores em várias variáveis de um gráfico

# %%
df.head()
# Out:
#                 Continente           Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia      Sul da Ásia    16    39    39    47    71
# Albânia             Europa    Sul da Europa     1     0     0     0     0
# Argélia             África  Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia        Polinésia     0     1     0     0     0
# Andorra             Europa    Sul da Europa     0     0     0     0     0
#
#                  1985  1986  1987  ...  2005  2006  2007  2008  2009  2010  \
# País                               ...
# Afeganistão       340   496   741  ...  3436  3009  2652  2111  1746  1758
# Albânia             0     1     2  ...  1223   856   702   560   716   561
# Argélia            44    69   132  ...  3626  4807  3623  4005  5393  4752
# Samoa Americana     0     0     1  ...     0     1     0     0     0     0
# Andorra             0     2     0  ...     0     1     1     0     0     0
#
# ...

# %%
paises_america_do_sul = df.query('Região == "América do Sul"')
paises_america_do_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Guiana     América Latina e o Caribe  América do Sul  2334  2943  3575  2650
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# ...

# %%
america_sul_sorted = paises_america_do_sul.sort_values('Total', ascending=True) # ordenando os valore de total para aperecer de forma ordenada no gráfico

# %%
cores = []

for pais in america_sul_sorted.index:
  if pais == 'Brasil':
    cores.append('green')
  else:
    cores.append('silver')

fig, ax = plt.subplots(figsize=(12,5))

ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('Imigração da américa do Sul para o Canadá\n1980-2013', loc='left', fontsize=18)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

# adicionando rótulo de dados
for i, v in enumerate(america_sul_sorted['Total']):
  ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va='center')

# retirando o contorno do gráfico
ax.set_frame_on(False)

# tirando os valores do eixo x
ax.get_xaxis().set_visible(False)

# tirando uma pequena marcação nas barras no eixo y
ax.tick_params(axis='both', which='both', length=0)

fig.savefig('migracao_america_sul_canada', transparent=False, dpi=300, bbox_inches='tight')

plt.show()
# print(fig.canvas.get_supported_filetypes()), comando para verificar os tipos de arquivos disponíveis para salvar a imagem

# %% [markdown]
# # **Estilos**

# %%
# printando estilos disponíveis para usar nos gráficos
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('default') # usando um estilo no gráfico. muda de todos os gráficos do notebook

fig, ax = plt.subplots(figsize=(8,4))

ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3, marker='o', color='g') # lw -> aumentar espessura da linha
ax.set_title('Imigração do Brasil para o Canadá\n1980-2013', fontsize=18, loc='left') # loc -> serve para alterarmos onde o título vai ficar disposto
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Número de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12) # alterando o tamanho dos valores do eixo x
ax.yaxis.set_tick_params(labelsize=12) # alterando o tamanho dos valores do eixo y
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # colocando os anos de 5 em 5 de forma mais fácil
# plt.grid(linestyle='--') adiciona grade ao gráfico

# retirando o contorno do gráfico da linha superior e direita
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# transperent = False (fundo transparente?)
fig.savefig('imigracao_brasil_canada.png', transparent=False, dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# # **Exercício 03**
#
# Mais uma etapa de desafio se inicia! Aproveite a oportunidade proposta e mergulhe nas possibilidades. Na aula anterior, você teve o desafio de criar uma figura com subplots que apresentam a variação no número de vendas em quatro diferentes lojas ao longo de um ano. Agora é o momento de elevar essa figura a um novo patamar! É a hora de personalizá-la! Nesta segunda parte do desafio, você deve explorar as opções de customização dos subplots para deixar a figura mais clara e atraente para a gerência da empresa.
#
# Algumas ideias de customização que você pode explorar são:
#
# Alterar a posição dos títulos dos subplots para esquerda.
# Aumentar o tamanho da fonte do título geral da figura para destacá-lo.
# Aumentar o tamanho dos títulos e rótulos dos eixos dos subplots.
# Deixar as linhas com a espessura maior.
# Alterar a cor das linhas de cada loja para diferenciá-las ainda mais.

# %%
lojas = ['A', 'B', 'C', 'D']

vendas_2022 = {'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250]
}

# %%
df_desafio = pd.DataFrame(vendas_2022, index=lojas)
df_desafio
# Out:
#    Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
cores = ['darkviolet', 'green', 'darkblue', 'coral']

# %%
fig, axs = plt.subplots(2,2, figsize=(12,6))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle('Indíce de vendas para as lojas A, B, C e D')

for i, ax in enumerate(axs.flat):
    ax.plot(df_desafio.loc[df_desafio.index[i]], color=cores[i], lw=3)
    ax.set_title(f'Vendas na loja {df.index[i]}', loc='left', fontsize=16)
    ax.set_xlabel('Mês', fontsize=14)
    ax.set_ylabel('Número de vendas', fontsize=14)
    ax.tick_params(labelsize=12)
    ax.grid(color='lightgrey')

# %%
import seaborn as sns

# %%
sns.set_theme(style='white', palette='tab10')

# %%
top_10 = df.sort_values('Total', ascending=False).head(10)
top_10
# Out:
#                                       Continente            Região   1980  \
# País
# Índia                                       Ásia       Sul da Ásia   8880
# China                                       Ásia     Ásia Oriental   5123
# Reino Unido e Irlanda do Norte            Europa   Norte da Europa  22045
# Filipinas                                   Ásia  Sudeste Asiático   6051
# Paquistão                                   Ásia       Sul da Ásia    978
# Estados Unidos da América       América do Norte  América do Norte   9378
# Irã                                         Ásia       Sul da Ásia   1172
# Sri Lanka                                   Ásia       Sul da Ásia    185
# República da Coreia                         Ásia     Ásia Oriental   1011
# Polônia                                   Europa   Europa Oriental    863
#
#                                  1981   1982   1983   1984  1985  1986   1987  \
# País
# ...

# %%
sns.barplot(data=top_10, x=top_10.index, y='Total')
# Out:
# <Axes: xlabel='País', ylabel='Total'>

# %%
sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h')
# Out:
# <Axes: xlabel='Total', ylabel='País'>

# %%
ax = sns.barplot(data=top_10, y=top_10.index, x='Total')

ax.set(title='Países com maior imigração para o Canadá\n1980-2013',
       xlabel='Número de imigrantes',
       ylabel='')

plt.show()

# %%
ax, fig = plt.subplots(figsize=(10,5))

ax = sns.barplot(data=top_10, x=top_10['Total'], y=top_10.index)

ax.set_title('Países com maiores taxas de imigração para o Canadá\n1980 - 2013', loc='left', fontsize=16)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
def gerar_grafico_paleta(palette):
  fig, ax = plt.subplots(figsize=(8,4))
  ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette=palette)
  ax.set_title('Países com maior imigração para o Canadá\n1980 - 2013', loc='left', fontsize=18)
  ax.set_xlabel('Número de imigrantes', fontsize=14)
  ax.set_ylabel('')

  plt.show();

# %%
gerar_grafico_paleta('Blues')
# Out:
# <ipython-input-293-a503a524bd2b>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
gerar_grafico_paleta('Blues_r') #_r -> reverse
# Out:
# <ipython-input-293-a503a524bd2b>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
gerar_grafico_paleta('rocket')
# Out:
# <ipython-input-293-a503a524bd2b>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
gerar_grafico_paleta('coolwarm')
# Out:
# <ipython-input-293-a503a524bd2b>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
gerar_grafico_paleta('tab10')
# Out:
# <ipython-input-293-a503a524bd2b>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.set_theme(style='dark')
gerar_grafico_paleta('tab10')
# Out:
# <ipython-input-293-a503a524bd2b>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.set_theme(style='whitegrid')
gerar_grafico_paleta('tab10')
# Out:
# <ipython-input-293-a503a524bd2b>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.set_theme(style='white')
gerar_grafico_paleta('tab10')
# Out:
# <ipython-input-293-a503a524bd2b>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.set_theme(style='ticks')
gerar_grafico_paleta('tab10')
# Out:
# <ipython-input-293-a503a524bd2b>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
fig, ax = plt.subplots(figsize=(8,4))

ax = sns.barplot(data=top_10, x='Total', y=top_10.index, orient='h', palette='tab10')
ax.set_title('Países com maior imigração para o Canadá\n1980 - 2013', fontsize=18)
ax.set_xlabel('Números de imigrantes', fontsize=14)
ax.set_ylabel('')

# tirando o contorno superior e da direita
sns.despine()

plt.show()
# Out:
# <ipython-input-303-c74547ab784a>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # **Exercício 03**
#
# Nesta etapa, seu desafio é criar uma figura contendo as tendências de imigração dos 4 maiores países da América latina: Brasil, Argentina, Peru e Colômbia. Através dessa criação você pode explorar diversas possibilidades e reconhecer de forma atrativa o seu processo de desenvolvimento.E não nos esqueçamos das orientações! Essa figura precisa ter uma linha para cada país, título, rótulos nos eixos, cores apropriadas, um tema da biblioteca Seaborn e legenda. Por isso, pense nas questões de acessibilidade, como tamanho das fontes e espessura das linhas. É importante escolher cores adequadas que não causem cansaço visual ou dificultem a leitura das informações. Além disso, o tamanho das fontes deve ser legível o suficiente para que as pessoas possam interpretar os dados com facilidade.

# %%
sns.set_theme()
sns.set_palette('Dark2')

# %%
fig, ax = plt.subplots(figsize=(8,4))

ax = sns.lineplot(df.loc['Brasil', anos], label='Brasil', lw=3)
ax = sns.lineplot(df.loc['Argentina', anos], label='Argentina', lw=3)
ax = sns.lineplot(df.loc['Peru', anos], label='Peru', lw=3)
ax = sns.lineplot(df.loc['Colômbia', anos], label='Colômbia', lw=3)

ax.set_title('Imigração dos maiores países da América do Sul\npara o Canadá de 1980 a 2013', loc='left', fontsize=20)

ax.xaxis.set_major_locator(plt.MultipleLocator(5))


# loc -> canto superior direito
ax.legend(title='Países', loc='upper right', bbox_to_anchor=(1.17, 1.05))

plt.show()

# %%
import plotly.express as px

# %%
fig = px.line(dados_brasil, x='ano', y='imigrantes', markers=True,
              title='Imigração do Brasil para o Canadá no período de 1980 a 2013')
fig.update_traces(line_color='green', line_width=4)

fig.update_layout(width=1000, height=500,
                  font_family='Arial',
                  font_size=14,
                  font_color='grey',
                  title_font_color='black',
                  title_font_size=18,
                  xaxis={'tickangle':-45}, # rotacionando o valor dos anos do eixo x
                  xaxis_title='Ano',
                  yaxis_title='Número de imigrantes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_america_sul_clean = paises_america_do_sul.drop(['Continente', 'Região', 'Total'], axis=1)
america_sul_final = df_america_sul_clean.T

# %%
america_sul_final.head()
# Out:
# País  Argentina  Bolívia  Brasil  Chile  Colômbia  Equador  Guiana  Paraguai  \
# 1980        368       44     211   1233       266      238    2334        45
# 1981        426       52     220   1069       326      207    2943        26
# 1982        626       42     192   1078       360      184    3575        32
# 1983        241       49     139    781       244      155    2650        40
# 1984        237       38     145    681       235      179    1932        48
#
# País  Peru  Suriname  Uruguai  Venezuela
# 1980   317        15      128        103
# 1981   456        10      132        117
# 1982   401        21      146        174
# 1983   241        12      105        124
# 1984   306         5       90        142

# %%
fig = px.line(america_sul_final, x=america_sul_final.index, y=america_sul_final.columns, color='País',
              title='Imigração dos países da américa do sul para o Canadá (1980 - 2013)',
              markers=True)

fig.update_layout(
    xaxis={'tickangle':45},
    xaxis_title='Ano',
    yaxis_title='Número de imigrantes'
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html('imigracao_america_sul.html')
